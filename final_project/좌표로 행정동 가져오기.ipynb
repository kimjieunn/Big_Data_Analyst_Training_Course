# %% [markdown]
# ## store

# %%
import json
import sys
import pandas as pd
import requests
from datetime import *

# 전역 변수
store_data = 'store.csv'
APP_KEY = '036b4aabe184d815e9256e99abea3367'    # 발급받은 키 입력
URL = 'https://dapi.kakao.com/v2/local/geo/coord2regioncode.json'

# %%
def json_request(url='', encoding='utf-8', success=None, error=lambda e: print('%s : %s' % (e, datetime.now()), file=sys.stderr)):
    headers = {'Authorization': 'KakaoAK {}'.format(APP_KEY)}
    resp = requests.get(url, headers=headers)
    print('%s : success for request [%s]' % (datetime.now(), url))

    return resp.text

# %%
def reverse_geocode(longitude, latitude):
    # 파라미터 최적화하여 url 생성
    url = '%s?x=%s&y=%s' %(URL, longitude, latitude)

    # json request
    try:
        json_req = json_request(url=url)
        json_data = json.loads(json_req)
        json_doc = json_data.get('documents')[1]
        json_name = json_doc.get('region_3depth_name')
    except:
        json_name = 'NaN'

    return json_name

# %%
def get_address(data):
    address = []

    # 경도, 위도 추출해서 동 주소 반환
    for i in range(len(data)):
        longitude = data['경도'][i]
        latitude = data['위도'][i]
        address.append(reverse_geocode(longitude, latitude))

    return address  # 전처리 함수에서 주소 리스트 받아서 데이터프레임에 추가

# %%
def main():
    # 파일 읽기
    data = pd.read_csv(store_data, encoding='utf-8')

    address = get_address(data)
#     data = preprocess(data, address)  # 전처리 함수(생략했음)
#     ad = pd.DataFrame(address)
    data['dong_name']=address

    # 최종 파일 저장
    data.to_csv('store_ex.csv', encoding='utf-8-sig')

if __name__ == '__main__':
    main()
# Out:
# 2022-11-30 13:33:41.387541 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=126.8465139&y=37.5648129]
# 2022-11-30 13:33:41.465556 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=126.8254241&y=37.5680891]
# 2022-11-30 13:33:41.543896 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=126.8391073&y=37.5687962]
# 2022-11-30 13:33:41.624456 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=126.8421371&y=37.5706528]
# 2022-11-30 13:33:41.702148 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=126.8250215&y=37.5627418]
# 2022-11-30 13:33:41.795865 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=127.0381648&y=37.6614209]
# 2022-11-30 13:33:41.873081 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=127.0231295&y=37.6312397]
# ...

# %% [markdown]
# ## park

# %%
import json
import sys
import pandas as pd
import requests
from datetime import *

# 전역 변수
park_data = 's_park.csv'
APP_KEY = '036b4aabe184d815e9256e99abea3367'    # 발급받은 키 입력
URL = 'https://dapi.kakao.com/v2/local/geo/coord2regioncode.json'

# %%
def json_request(url='', encoding='utf-8', success=None, error=lambda e: print('%s : %s' % (e, datetime.now()), file=sys.stderr)):
    headers = {'Authorization': 'KakaoAK {}'.format(APP_KEY)}
    resp = requests.get(url, headers=headers)
    print('%s : success for request [%s]' % (datetime.now(), url))

    return resp.text

# %%
def reverse_geocode(longitude, latitude):
    # 파라미터 최적화하여 url 생성
    url = '%s?x=%s&y=%s' %(URL, longitude, latitude)

    # json request
    try:
        json_req = json_request(url=url)
        json_data = json.loads(json_req)
        json_doc = json_data.get('documents')[1]
        json_name = json_doc.get('region_3depth_name')
    except:
        json_name = 'NaN'

    return json_name

# %%
def get_address(data):
    address = []

    # 경도, 위도 추출해서 동 주소 반환
    for i in range(len(data)):
        longitude = data['X좌표(WGS84)'][i]
        latitude = data['Y좌표(WGS84)'][i]
        address.append(reverse_geocode(longitude, latitude))

    return address  # 전처리 함수에서 주소 리스트 받아서 데이터프레임에 추가

# %%
def main():
    # 파일 읽기
    data = pd.read_csv(park_data, encoding='cp949')

    address = get_address(data)
#     data = preprocess(data, address)  # 전처리 함수(생략했음)
#     ad = pd.DataFrame(address)
    data['dong_name']=address

    # 최종 파일 저장
    data.to_csv('park_final.csv', encoding='utf-8-sig',index=False)

if __name__ == '__main__':
    main()
# Out:
# 2022-11-30 10:40:32.909648 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=126.9903773&y=37.5501402]
# 2022-11-30 10:40:33.003457 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=127.1547791&y=37.5403935]
# 2022-11-30 10:40:33.081081 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=127.0417982&y=37.5430717]
# 2022-11-30 10:40:33.161211 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=126.878907&y=37.571805]
# 2022-11-30 10:40:33.239738 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=126.9780227&y=37.5750449]
# 2022-11-30 10:40:33.333669 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=126.9192155&y=37.6370244]
# 2022-11-30 10:40:33.411644 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=126.9112668&y=37.519832]
# ...

# %% [markdown]
# ## culture

# %%
import json
import sys
import pandas as pd
import requests
from datetime import *

# 전역 변수
culture_data = 'culture.csv'
APP_KEY = '036b4aabe184d815e9256e99abea3367'    # 발급받은 키 입력
URL = 'https://dapi.kakao.com/v2/local/geo/coord2regioncode.json'

# %%
def json_request(url='', encoding='utf-8', success=None, error=lambda e: print('%s : %s' % (e, datetime.now()), file=sys.stderr)):
    headers = {'Authorization': 'KakaoAK {}'.format(APP_KEY)}
    resp = requests.get(url, headers=headers)
    print('%s : success for request [%s]' % (datetime.now(), url))

    return resp.text

# %%
def reverse_geocode(longitude, latitude):
    # 파라미터 최적화하여 url 생성
    url = '%s?x=%s&y=%s' %(URL, longitude, latitude)

    # json request
    try:
        json_req = json_request(url=url)
        json_data = json.loads(json_req)
        json_doc = json_data.get('documents')[1]['address']
        json_name = json_doc.get('region_2depth_name')
    except:
        json_name = 'NaN'

    return json_name

# %%
def get_address(data):
    address = []

    # 경도, 위도 추출해서 동 주소 반환
    for i in range(len(data)):
        longitude = data['경도'][i]
        latitude = data['위도'][i]
        address.append(reverse_geocode(longitude, latitude))

    return address  # 전처리 함수에서 주소 리스트 받아서 데이터프레임에 추가

# %%
def main():
    # 파일 읽기
    data = pd.read_csv(culture_data, encoding='utf-8')

    address = get_address(data)
#     data = preprocess(data, address)  # 전처리 함수(생략했음)
#     ad = pd.DataFrame(address)
    data['gu_name']=address

    # 최종 파일 저장
    data.to_csv('culture_gu.csv', encoding='cp949')

if __name__ == '__main__':
    main()
# Out:
# 2022-11-30 11:25:59.048404 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=127.0493018&y=37.59508001]
# 2022-11-30 11:25:59.127089 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=127.0096257&y=37.56681313]
# 2022-11-30 11:25:59.204947 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=127.0544189&y=37.5437895]
# 2022-11-30 11:25:59.298233 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=126.9331183&y=37.6372304]
# 2022-11-30 11:25:59.376945 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=127.0802693&y=37.65023586]
# 2022-11-30 11:25:59.454943 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=126.9343404&y=37.60933472]
# 2022-11-30 11:25:59.535097 : success for request [https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=126.9991712&y=37.58868966]
# ...
